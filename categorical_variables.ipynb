# %%
import pandas as pd
import os

# %%
movies = pd.read_csv('P4-Movie-Ratings.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movies.Year.cat.categories
# Out:
# Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# #### JointPlots

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hex')

# %% [markdown]
# Histogram

# %%
sns.set_style('darkgrid')
m1 = sns.displot(movies.CriticRating, bins=15)

# %%
m2 = sns.displot(movies.AudienceRating, bins=15)

# %%
n1 = plt.hist(movies.AudienceRating, bins=15)

# %%
m3 = sns.histplot(movies.CriticRating, bins=15)

# %% [markdown]
# Stacked Histograms

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
movies.Genre == "Drama"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# Name: Genre, Length: 559, dtype: bool

# %%
movies[movies.Genre == "Drama"]
# Out:
#                     Film  Genre  CriticRating  AudienceRating  BudgetMillions  \
# 10            88 Minutes  Drama             5              51              30
# 11    A Dangerous Method  Drama            79              89              20
# 13        A Serious Man   Drama            89              64               7
# 18          Albert Nobbs  Drama            53              43               8
# 23       All Good Things  Drama            33              64              20
# ..                   ...    ...           ...             ...             ...
# 529            War Horse  Drama            77              73              66
# 532  Water For Elephants  Drama            60              72              38
# 534     We Own the Night  Drama            55              63              21
# 541             Whip It   Drama            84              73              15
# 545        Winter's Bone  Drama            94              73               2
#
#      Year
# 10   2007
# ...

# %%
movies[movies.Genre == "Drama"].BudgetMillions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.Genre == "Action"].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == "Drama"].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == "Thriller"].BudgetMillions, bins=15)
plt.show()

# %%
movies_lst = [movies[movies.Genre == "Action"].BudgetMillions, movies[movies.Genre == "Drama"].BudgetMillions, movies[movies.Genre == "Thriller"].BudgetMillions, movies[movies.Genre == "Comedy"].BudgetMillions]

plt.hist(movies_lst, bins=15, stacked=True)
plt.show()

# %%
# using a loop
list1 = []
my_labels = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    my_labels.append(gen)
h = plt.hist(list1, bins=30, stacked=True, rwidth=1,  label=my_labels)
plt.legend()
plt.show()

# %% [markdown]
# Kernel Density Estimation (KDE Plot)

# %%
k1 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, shade=True, thresh=0.05)

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, shade=True, thresh=0.05)

# %%
k2 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticRating, shade=True, thresh=0.05)

# %% [markdown]
# Subplots

# %%
f, ax = plt.subplots(1, 2, figsize=(12,6), sharex=True, sharey=True)

# %%
f, axes = plt.subplots(1, 2, figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, shade=True, thresh=0.05, ax=axes[0])
k2 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticRating, shade=True, thresh=0.05, axes=axes[1])

# %%
plt.pie(movies.Genre.value_counts(), labels=movies.Genre.value_counts().index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ViolinPlots vs BoxPlots

# %%
w = sns.boxplot(data=movies, x='Genre', y='CriticRating', palette='coolwarm')

# %%
z = sns.violinplot(data=movies, x='Genre', y='CriticRating', palette='coolwarm')

# %%
sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating', palette='coolwarm')
plt.show()

# %%
sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating', palette='coolwarm')
plt.show()

# %% [markdown]
# Facet Grids

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist, 'CriticRating')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)

# %% [markdown]
# Coordinates and Diagonals

# %%
# Controlling axes and adding a title
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c='grey', ls='--')
g.add_legend()

# %% [markdown]
# ### Dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2, 2, figsize=(15,15))
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, shade=True, thresh=0.05, ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticRating, shade=True, thresh=0.05, ax=axes[0,1])
k4 = sns.boxplot(data=movies, x='Genre', y='CriticRating', palette='coolwarm', ax=axes[1,0])
k5 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, shade=True, thresh=0.05, ax=axes[1,1])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Styling Dashboards

# %%
sns.set_style('dark', {'axes.facecolor': 'black'})
f, axes = plt.subplots(2, 2, figsize=(15,15))

# Plot [0,0]
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, shade=True, thresh=0.05, ax=axes[0,0], shade_lowest=True, cmap='inferno')
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, thresh=0.05, ax=axes[0,0], cmap='cool')


# Plot [0,1]
k2 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticRating, shade=True, thresh=0.05, ax=axes[0,1], cmap='inferno', shade_lowest=True)
k2b = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticRating, thresh=0.05, ax=axes[0,1], cmap='cool')

# Plot [1,0]
k3 = sns.boxenplot(data=movies, x='Genre', y='BudgetMillions', palette='YlOrRd', ax=axes[1,0])

# Plot [1,1]
k4 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, shade=True, thresh=0.05, ax=axes[1,1], cmap='Blues_r', shade_lowest=True)
k4b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, ax=axes[1,1], cmap='cool')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/_compat.py:62, in get_colormap(name)
#      61 try:
# ---> 62     return mpl.colormaps[name]
#      63 except AttributeError:
#
# ...

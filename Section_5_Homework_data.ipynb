# %% [markdown]
# ## Section 5
# ### Homework data
# #### Lists

# %% [markdown]
# Country code and life expectancy at birth in 1960 and 2013

# %% [markdown]
# Country names, codes and regions dataset

# %% [markdown]
# (c) Kirill Eremenko, www.superdatascience.com

# %% [markdown]
# ## Solutions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stats = pd.read_excel("Life-Expectancy-At-Birth.xls")

# %%
stats
# Out:
#          Country Name Country Code                           Indicator Name  \
# 0               Aruba          ABW  Life expectancy at birth, total (years)
# 1             Andorra          AND  Life expectancy at birth, total (years)
# 2         Afghanistan          AFG  Life expectancy at birth, total (years)
# 3              Angola          AGO  Life expectancy at birth, total (years)
# 4             Albania          ALB  Life expectancy at birth, total (years)
# ..                ...          ...                                      ...
# 210       Yemen, Rep.          YEM  Life expectancy at birth, total (years)
# 211      South Africa          ZAF  Life expectancy at birth, total (years)
# 212  Congo, Dem. Rep.          COD  Life expectancy at birth, total (years)
# 213            Zambia          ZMB  Life expectancy at birth, total (years)
# 214          Zimbabwe          ZWE  Life expectancy at birth, total (years)
#
#      Indicator Code       1960       1961       1962       1963       1964  \
# 0    SP.DYN.LE00.IN  65.569366  65.988024  66.365537  66.713976  67.044293
# 1    SP.DYN.LE00.IN        NaN        NaN        NaN        NaN        NaN
# 2    SP.DYN.LE00.IN  31.580049  32.095976  32.611878  33.127317  33.641244
# 3    SP.DYN.LE00.IN  32.984829  33.386220  33.787585  34.188463  34.590341
# 4    SP.DYN.LE00.IN  62.254366  63.273463  64.162854  64.887098  65.438195
# ..              ...        ...        ...        ...        ...        ...
# 210  SP.DYN.LE00.IN  32.385659  33.320537  34.246439  35.161829  36.065732
# 211  SP.DYN.LE00.IN  49.036293  49.429805  49.813293  50.195756  50.581756
# 212  SP.DYN.LE00.IN  41.018049  41.233537  41.451512  41.678000  41.918000
# 213  SP.DYN.LE00.IN  45.109805  45.487512  45.853659  46.209220  46.558683
# 214  SP.DYN.LE00.IN  51.542463  51.914951  52.277902  52.629317  52.971659
#
#           1965  ...       2004       2005       2006       2007       2008  \
# 0    67.369756  ...  74.090854  74.228073  74.375707  74.526244  74.674220
# 1          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 2    34.153683  ...  56.569732  57.058439  57.570659  58.091366  58.607098
# 3    34.992220  ...  48.003512  48.538805  49.007049  49.435732  49.847390
# 4    65.827390  ...  75.839000  76.089390  76.290537  76.464854  76.632317
# ..         ...  ...        ...        ...        ...        ...        ...
# 210  36.953659  ...  61.328659  61.534927  61.738659  61.939780  62.137829
# 211  50.971829  ...  51.873756  51.557341  51.613707  51.996512  52.636024
# 212  42.180488  ...  47.599122  47.821610  48.015537  48.213512  48.439585
# 213  46.913024  ...  45.765000  47.128341  48.584927  50.098537  51.622146
# 214  53.304463  ...  43.178244  43.888390  45.084268  46.749732  48.808341
#
#           2009       2010       2011       2012       2013
# 0    74.816146  74.952024  75.080390  75.206756  75.332171
# 1          NaN        NaN        NaN        NaN        NaN
# 2    59.112341  59.600098  60.065366  60.509122  60.931415
# 3    50.251024  50.654171  51.059317  51.464000  51.866171
# 4    76.801878  76.978512  77.163220  77.350463  77.537244
# ..         ...        ...        ...        ...        ...
# 210  62.333780  62.527659  62.718488  62.905780  63.089585
# 211  53.467098  54.390756  55.295659  56.098317  56.736585
# 212  48.697805  48.987683  49.300707  49.623268  49.943854
# 213  53.113366  54.527561  55.833146  57.022585  58.092780
# 214  51.147927  53.593122  55.946220  58.045976  59.773488
#
# [215 rows x 58 columns]

# %% [markdown]
# Dropping unwanted columns

# %%
stats = stats.drop(columns=[str(year) for year in range(1961, 2013)])

# %%
stats = stats.drop(stats.columns[2:3], axis=1)

# %%
stats
# Out:
#          Country Name Country Code       1960       2013
# 0               Aruba          ABW  65.569366  75.332171
# 1             Andorra          AND        NaN        NaN
# 2         Afghanistan          AFG  31.580049  60.931415
# 3              Angola          AGO  32.984829  51.866171
# 4             Albania          ALB  62.254366  77.537244
# ..                ...          ...        ...        ...
# 210       Yemen, Rep.          YEM  32.385659  63.089585
# 211      South Africa          ZAF  49.036293  56.736585
# 212  Congo, Dem. Rep.          COD  41.018049  49.943854
# 213            Zambia          ZMB  45.109805  58.092780
# 214          Zimbabwe          ZWE  51.542463  59.773488
#
# [215 rows x 4 columns]

# %%
stats.head()
# Out:
#   Country Name Country Code       1960       2013
# 0        Aruba          ABW  65.569366  75.332171
# 1      Andorra          AND        NaN        NaN
# 2  Afghanistan          AFG  31.580049  60.931415
# 3       Angola          AGO  32.984829  51.866171
# 4      Albania          ALB  62.254366  77.537244

# %%
plt.figure(figsize=(10, 6))

# %%
vis1 = sns.scatterplot(stats)
